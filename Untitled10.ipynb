# %%
import graphviz

import sklearn.datasets as datasets

import pandas as pd

# %% [markdown]
# **黑体**

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f84ab820532c> in <module>
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %% [markdown]
# ![aaa](C:\Users\l00165373\Pictures\download_icon.png)

# %% [markdown]
# ![wusuowei](http://image.baidu.com/search/detail?ct=503316480&z=0&ipn=d&word=%E5%9B%BE%E7%89%87&hs=0&pn=0&spn=0&di=21166381280&pi=0&rn=1&tn=baiduimagedetail&is=0%2C0&ie=utf-8&oe=utf-8&cl=2&lm=-1&cs=2735633715%2C2749454924&os=1423882261%2C1566996236&simid=4041337662%2C948052319&adpicid=0&lpn=0&ln=30&fr=ala&fm=&sme=&cg=&bdtype=0&oriquery=&objurl=http%3A%2F%2Fwww.pptbz.com%2Fpptpic%2FUploadFiles_6909%2F201203%2F2012031220134655.jpg&fromurl=ippr_z2C%24qAzdH3FAzdH3Fooo_z%26e3Brrpkz_z%26e3Bv54AzdH3FrrprtvAzdH3Frrprtv_80ln_z%26e3Bip4s&gsm=0&islist=&querylist=)

# %%
from IPython.display import Image

# %%
Image(filename='download_icon.png',width=600)

# %%
# %pwd
# Out:
# 'C:\\Users\\l00165373'
